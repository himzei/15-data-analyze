# %%
# 253a4c30c04bb49e805165b1e51adf1e
# !pip install requests

import requests
import pandas as pd

my_key = "49765fcbcf0fe5bc094eb6ec9b643b8f"

def get_geocoding(place): 
    url = f"https://dapi.kakao.com/v2/local/search/address.json?query={place}"
    headers= {
        "Authorization": f"KakaoAK {my_key}"
    }

    response = requests.get(url, headers=headers)
    result = response.json()

    
    print(result["documents"][0]["y"])
    print(result["documents"][0]["x"])

get_geocoding("서울특별시 종로구 세종대로 175")
# Out:
# 37.5718478584908
# 126.976168275947
